# %%
#import numpy as np
import matplotlib.pyplot as plt
import pims

# %%
v = pims.TiffStack('test.tif')
print('frames: ',len(v))
intensity=v[0]
lifetime=v[1]
# Out:
# frames:  2
# /opt/conda/lib/python3.6/site-packages/tifffile/tifffile.py:2159: UserWarning: tags are not ordered by code
#   warnings.warn("tags are not ordered by code")

# %%
fig = plt.figure(figsize=(6, 3.2))
ax = fig.add_subplot(111)
ax.set_title('intensity')
plt.imshow(intensity)
ax.set_aspect('equal')
cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show()

# %%
fig = plt.figure(figsize=(6, 3.2))
ax = fig.add_subplot(111)
ax.set_title('lifetime')
plt.imshow(lifetime,vmin=1.8E-9,vmax=3E-9) # This also sets the scale for the colormap to 1.8ns - 3ns
ax.set_aspect('equal')
cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show()
